# %% [markdown]
# <a href="https://colab.research.google.com/github/Samar090/Zeus_09/blob/main/Datavisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt
import io
import os
from google.colab import files
uploaded = files.upload()

current_directory = os.getcwd()

print("Current working directory:", current_directory)
# Out:
#      <input type="file" id="files-9933a9a0-af5e-4337-8711-ade2e4b00fc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9933a9a0-af5e-4337-8711-ade2e4b00fc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt
df=pd.read_excel(r'ic.xlsx')

df=df.set_index('Date')
print(df)
# Out:
#             Flavor Rating  Texture Rating  Overall Rating
# Date
# 2022-01-01       0.223090        0.040220        0.600129
# 2022-02-01       0.635886        0.938476        0.106264
# 2022-03-01       0.442323        0.044154        0.598112
# 2022-04-01       0.389128        0.549676        0.489353
# 2022-05-01       0.386887        0.519439        0.988280
# 2022-06-01       0.877984        0.193588        0.832827
# 2022-07-01       0.140995        0.325110        0.105147

# %%
print(plt.style.available)
plt.style.use('_mpl-gallery')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot(kind='line',xlabel="Date",title="Ice cream ratings",ylabel="Rating")
# Out:
# <Axes: title={'center': 'Ice cream ratings'}, xlabel='Date', ylabel='Rating'>

# %%
df.plot(kind='line',xlabel="Date",title="Ice cream ratings",ylabel="Rating",subplots=True)
# Out:
# array([<Axes: xlabel='Date', ylabel='Rating'>,
#        <Axes: xlabel='Date', ylabel='Rating'>,
#        <Axes: xlabel='Date', ylabel='Rating'>], dtype=object)

# %%
df.plot(kind='bar',xlabel="Date",title="Ice cream ratings",ylabel="Rating")
# Out:
# <Axes: title={'center': 'Ice cream ratings'}, xlabel='Date', ylabel='Rating'>

# %%
df.plot(kind='bar',xlabel="Date",title="Ice cream ratings",ylabel="Rating",stacked=True)
# Out:
# <Axes: title={'center': 'Ice cream ratings'}, xlabel='Date', ylabel='Rating'>

# %%
df['Overall Rating'].plot(kind='bar',xlabel="Date",title="Ice cream ratings",ylabel="Rating",stacked=True)
# Out:
# <Axes: title={'center': 'Ice cream ratings'}, xlabel='Date', ylabel='Rating'>

# %%
df.plot.barh(xlabel="Date",title="Ice cream ratings",ylabel="Rating",stacked=True)
df.plot.barh(xlabel="Date",title="Ice cream ratings",ylabel="Rating")
# Out:
# <Axes: title={'center': 'Ice cream ratings'}, xlabel='Date', ylabel='Rating'>

# %%
df.plot.scatter(x="Flavor Rating",y="Overall Rating",s=100,c='orange')
# Out:
# <Axes: xlabel='Flavor Rating', ylabel='Overall Rating'>

# %%
df.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize=(10,10))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y="Overall Rating")
# Out:
# <Axes: ylabel='upperright'>
